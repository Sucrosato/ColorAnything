# %%
import torch
import d2l
from cocoloader import cocoloader
from model.ColorAnything import ColorAnything

# %%
net = ColorAnything()
# Out:
# Backbone does not define embed_dims, using [embed_dim] * n_blocks=[384, 384, 384, 384, 384, 384, 384, 384, 384, 384, 384, 384] instead
# Backbone does not define input_pad_size, using patch_size=16 instead
# c:\ProgramData\miniconda3\envs\rgb\lib\site-packages\torch\functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:4324.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
train_iter = cocoloader(r'E:\work\Code\ColorAnything\data\train_small', batch_size=4)
test_iter = cocoloader(r'E:\work\Code\ColorAnything\data\test_small', batch_size=4)
num_epochs = 3
lr = 5e-5
trainer = torch.optim.AdamW(net.parameters(), lr=lr)
d2l.train_ch13(net, train_iter, test_iter, nn.MSELoss(), trainer, num_epochs)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_iter = cocoloader('data/train_small', batch_size=4)
#       2 test_iter = cocoloader('data/test_small', batch_size=4)
#       3 num_epochs = 3
#
# File e:\work\Code\ColorAnything\ColorAnything\cocoloader.py:60, in cocoloader(img_dir, batch_size, shuffle, num_workers, input_size)
#      59 def cocoloader(img_dir, batch_size=16, shuffle=True, num_workers=4, input_size=224):
# ---> 60     dataset = COCOColorInversionDataset(img_dir, input_size=input_size)
#      61     dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, pin_memory=True)
#      62     return dataloader
#
# File e:\work\Code\ColorAnything\ColorAnything\cocoloader.py:10, in COCOColorInversionDataset.__init__(self, img_dir, input_size)
#       8 def __init__(self, img_dir, input_size=224):
#       9     self.img_dir = img_dir
# ---> 10     self.img_names = [f for f in os.listdir(img_dir) if f.endswith('.jpg')]
#      11     self.input_size = input_size
#      13     self.mean = np.array([0.485, 0.456, 0.406])
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: 'data/train_small'
